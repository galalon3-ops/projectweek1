# %%
# Python course for beginners
import numpy as np
number=range(1,7)
gender1= ["female,male"]
random_gender=
data = {
"number":number,
"gender":np.random.choice(gender1,size=6, replace=True),
"age": np.random.randint (15,40,6),
"depression": np.random.binomial(n=1, p=0.5, size=6)
import pandas as pd
# Week 1
# assignment by Gal Alon 212537831
}
df1 = pd.DataFrame(data)
df1.to_csv("my_data.csv")
